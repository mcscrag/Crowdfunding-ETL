# %%
import pandas as pd
import json

# %% [markdown]
# ## Deliverable 1: Extract
# ----
# ### Option 1: Use Python Dictionary Methods
#
# 1. Import the `backer_info.csv` file into a DataFrame.
# 2. Iterate through the DataFrame and convert each row to a dictionary.
# 3. Iterate through each dictionary and do the following:
#     * Extract the dictionary values from the keys using Python list comprehension.
#     * Add the values for each row to a new list.
# 4. Create a new DataFrame with the retrieved data.
# 5. Export the DataFrame as `backers_data.csv`.

# %%
# Get the backers_info from the crowdfunding_info sheet. 
pd.set_option('max_colwidth', 400)
backers_file = 'Resources/backer_info.csv'
backer_df = pd.read_csv(backers_file, sep='/n')
backer_df.head()
# Out:
# C:\Users\brend\AppData\Local\Temp\ipykernel_12464\3195410492.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   backer_df = pd.read_csv(backers_file, sep='/n')
#                                                                                                           backer_info
# 0        "{""backer_id"": ""av166"", ""cf_id"": 968, ""name"": ""Angelo Vincent"", ""email"": ""avincent@live.com""}"
# 1        "{""backer_id"": ""ha127"", ""cf_id"": 563, ""name"": ""Hubert Arnold"", ""email"": ""harnold@yandex.com""}"
# 2          "{""backer_id"": ""lg794"", ""cf_id"": 65, ""name"": ""Loris Goulet"", ""email"": ""lgoulet@yandex.com""}"
# 3  "{""backer_id"": ""tb566"", ""cf_id"": 563, ""name"": ""Teodora Brunelli"", ""email"": ""tbrunelli@outlook.com""}"
# 4               "{""backer_id"": ""lh506"", ""cf_id"": 563, ""name"": ""Lexie Hunt"", ""email"": ""lhunt@live.com""}"

# %%
# Iterate through the backers DataFrame and convert each row to a dictionary.

    # Iterate through each dictionary (row) and get the values for each row using list comprehension.
    
    # Append the list of values for each row to a list. 
    

# Print out the list of values for each row.

# %%
# Create a backers_df DataFrame with the following columns: 'backer_id','cf_id', 'name', and 'email' 
# using the list of values lists.

# %%
# Export the DataFrame as a CSV file using encoding='utf8'.

# %% [markdown]
# ## Deliverable 1: Extract
# ----
# ### Option 2: Use regex
#
# 1. Import the `backer_info.csv` file into a DataFrame.
# 2. Extract the "backer_id", "cf_id", "name", and "email using regular expressions."
# 3. Create a new DataFrame with the retrieved data.
# 4. Export the DataFrame as `backers_data.csv`.

# %%
# Get the backers_info from the crowdfunding_info sheet. 
pd.set_option('max_colwidth', 400)

# %%
# Extract the alpha-numeric "backer_id" from the backer_info column using a regex expression 
# and add it as a new column called "backer_id".

backer_df['backer_id'] = backer_df['backer_info'].str.extract('(\D{2}\d{3})')
backer_df
# Out:
#                                                                                                              backer_info  \
# 0           "{""backer_id"": ""av166"", ""cf_id"": 968, ""name"": ""Angelo Vincent"", ""email"": ""avincent@live.com""}"
# 1           "{""backer_id"": ""ha127"", ""cf_id"": 563, ""name"": ""Hubert Arnold"", ""email"": ""harnold@yandex.com""}"
# 2             "{""backer_id"": ""lg794"", ""cf_id"": 65, ""name"": ""Loris Goulet"", ""email"": ""lgoulet@yandex.com""}"
# 3     "{""backer_id"": ""tb566"", ""cf_id"": 563, ""name"": ""Teodora Brunelli"", ""email"": ""tbrunelli@outlook.com""}"
# 4                  "{""backer_id"": ""lh506"", ""cf_id"": 563, ""name"": ""Lexie Hunt"", ""email"": ""lhunt@live.com""}"
# ...                                                                                                                  ...
# 8170     "{""backer_id"": ""st581"", ""cf_id"": 65, ""name"": ""Serita Thebault"", ""email"": ""sthebault@yandex.com""}"
# 8171    "{""backer_id"": ""gf637"", ""cf_id"": 563, ""name"": ""Glenn Foerstner"", ""email"": ""gfoerstner@yahoo.com""}"
# 8172        "{""backer_id"": ""rc983"", ""cf_id"": 1114, ""name"": ""Robt Collin"", ""email"": ""rcollin@outlook.com""}"
# 8173          "{""backer_id"": ""cz381"", ""cf_id"": 65, ""name"": ""Corina Zappa"", ""email"": ""czappa@outlook.com""}"
# 8174         "{""backer_id"": ""fg535"", ""cf_id"": 65, ""name"": ""Freeman Gibbs"", ""email"": ""fgibbs@outlook.com""}"
#
#      backer_id
# 0        av166
# 1        ha127
# 2        lg794
# 3        tb566
# 4        lh506
# ...        ...
# 8170     st581
# 8171     gf637
# 8172     rc983
# 8173     cz381
# 8174     fg535
#
# [8175 rows x 2 columns]

# %%
backer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8175 entries, 0 to 8174
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   backer_info  8175 non-null   object
#  1   backer_id    8175 non-null   object
# dtypes: object(2)
# memory usage: 127.9+ KB

# %%
# Extract the two to four-digit "cf_id" number from the backer_info column. 
# and add it as a new column called "cf_id".
backer_df['cf_id'] = backer_df['backer_info'].str.extract('(?!:""cf_id"":)\s(\d+),')
backer_df
# Out:
#                                                                                                              backer_info  \
# 0           "{""backer_id"": ""av166"", ""cf_id"": 968, ""name"": ""Angelo Vincent"", ""email"": ""avincent@live.com""}"
# 1           "{""backer_id"": ""ha127"", ""cf_id"": 563, ""name"": ""Hubert Arnold"", ""email"": ""harnold@yandex.com""}"
# 2             "{""backer_id"": ""lg794"", ""cf_id"": 65, ""name"": ""Loris Goulet"", ""email"": ""lgoulet@yandex.com""}"
# 3     "{""backer_id"": ""tb566"", ""cf_id"": 563, ""name"": ""Teodora Brunelli"", ""email"": ""tbrunelli@outlook.com""}"
# 4                  "{""backer_id"": ""lh506"", ""cf_id"": 563, ""name"": ""Lexie Hunt"", ""email"": ""lhunt@live.com""}"
# ...                                                                                                                  ...
# 8170     "{""backer_id"": ""st581"", ""cf_id"": 65, ""name"": ""Serita Thebault"", ""email"": ""sthebault@yandex.com""}"
# 8171    "{""backer_id"": ""gf637"", ""cf_id"": 563, ""name"": ""Glenn Foerstner"", ""email"": ""gfoerstner@yahoo.com""}"
# 8172        "{""backer_id"": ""rc983"", ""cf_id"": 1114, ""name"": ""Robt Collin"", ""email"": ""rcollin@outlook.com""}"
# 8173          "{""backer_id"": ""cz381"", ""cf_id"": 65, ""name"": ""Corina Zappa"", ""email"": ""czappa@outlook.com""}"
# 8174         "{""backer_id"": ""fg535"", ""cf_id"": 65, ""name"": ""Freeman Gibbs"", ""email"": ""fgibbs@outlook.com""}"
#
#      backer_id cf_id
# 0        av166   968
# 1        ha127   563
# 2        lg794    65
# 3        tb566   563
# 4        lh506   563
# ...        ...   ...
# 8170     st581    65
# 8171     gf637   563
# 8172     rc983  1114
# 8173     cz381    65
# 8174     fg535    65
#
# [8175 rows x 3 columns]

# %%
backer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8175 entries, 0 to 8174
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   backer_info  8175 non-null   object
#  1   backer_id    8175 non-null   object
#  2   cf_id        8175 non-null   object
# dtypes: object(3)
# memory usage: 191.7+ KB

# %%
# Extract the name from the backer_info column and add it as a new column called "name".
backer_df['name'] = backer_df['backer_info'].str.extract('(\w+\s\w+)')
backer_df
# Out:
#                                                                                                              backer_info  \
# 0           "{""backer_id"": ""av166"", ""cf_id"": 968, ""name"": ""Angelo Vincent"", ""email"": ""avincent@live.com""}"
# 1           "{""backer_id"": ""ha127"", ""cf_id"": 563, ""name"": ""Hubert Arnold"", ""email"": ""harnold@yandex.com""}"
# 2             "{""backer_id"": ""lg794"", ""cf_id"": 65, ""name"": ""Loris Goulet"", ""email"": ""lgoulet@yandex.com""}"
# 3     "{""backer_id"": ""tb566"", ""cf_id"": 563, ""name"": ""Teodora Brunelli"", ""email"": ""tbrunelli@outlook.com""}"
# 4                  "{""backer_id"": ""lh506"", ""cf_id"": 563, ""name"": ""Lexie Hunt"", ""email"": ""lhunt@live.com""}"
# ...                                                                                                                  ...
# 8170     "{""backer_id"": ""st581"", ""cf_id"": 65, ""name"": ""Serita Thebault"", ""email"": ""sthebault@yandex.com""}"
# 8171    "{""backer_id"": ""gf637"", ""cf_id"": 563, ""name"": ""Glenn Foerstner"", ""email"": ""gfoerstner@yahoo.com""}"
# 8172        "{""backer_id"": ""rc983"", ""cf_id"": 1114, ""name"": ""Robt Collin"", ""email"": ""rcollin@outlook.com""}"
# 8173          "{""backer_id"": ""cz381"", ""cf_id"": 65, ""name"": ""Corina Zappa"", ""email"": ""czappa@outlook.com""}"
# 8174         "{""backer_id"": ""fg535"", ""cf_id"": 65, ""name"": ""Freeman Gibbs"", ""email"": ""fgibbs@outlook.com""}"
#
#      backer_id cf_id              name
# 0        av166   968    Angelo Vincent
# 1        ha127   563     Hubert Arnold
# 2        lg794    65      Loris Goulet
# 3        tb566   563  Teodora Brunelli
# 4        lh506   563        Lexie Hunt
# ...        ...   ...               ...
# 8170     st581    65   Serita Thebault
# 8171     gf637   563   Glenn Foerstner
# 8172     rc983  1114       Robt Collin
# 8173     cz381    65      Corina Zappa
# 8174     fg535    65     Freeman Gibbs
#
# [8175 rows x 4 columns]

# %%
# Extract the email from the backer_info column and add it as a new column called "email".
backer_df['email'] = backer_df['backer_info'].str.extract('(\w+@\w+)')
backer_df
# Out:
#                                                                                                              backer_info  \
# 0           "{""backer_id"": ""av166"", ""cf_id"": 968, ""name"": ""Angelo Vincent"", ""email"": ""avincent@live.com""}"
# 1           "{""backer_id"": ""ha127"", ""cf_id"": 563, ""name"": ""Hubert Arnold"", ""email"": ""harnold@yandex.com""}"
# 2             "{""backer_id"": ""lg794"", ""cf_id"": 65, ""name"": ""Loris Goulet"", ""email"": ""lgoulet@yandex.com""}"
# 3     "{""backer_id"": ""tb566"", ""cf_id"": 563, ""name"": ""Teodora Brunelli"", ""email"": ""tbrunelli@outlook.com""}"
# 4                  "{""backer_id"": ""lh506"", ""cf_id"": 563, ""name"": ""Lexie Hunt"", ""email"": ""lhunt@live.com""}"
# ...                                                                                                                  ...
# 8170     "{""backer_id"": ""st581"", ""cf_id"": 65, ""name"": ""Serita Thebault"", ""email"": ""sthebault@yandex.com""}"
# 8171    "{""backer_id"": ""gf637"", ""cf_id"": 563, ""name"": ""Glenn Foerstner"", ""email"": ""gfoerstner@yahoo.com""}"
# 8172        "{""backer_id"": ""rc983"", ""cf_id"": 1114, ""name"": ""Robt Collin"", ""email"": ""rcollin@outlook.com""}"
# 8173          "{""backer_id"": ""cz381"", ""cf_id"": 65, ""name"": ""Corina Zappa"", ""email"": ""czappa@outlook.com""}"
# 8174         "{""backer_id"": ""fg535"", ""cf_id"": 65, ""name"": ""Freeman Gibbs"", ""email"": ""fgibbs@outlook.com""}"
#
#      backer_id cf_id              name              email
# 0        av166   968    Angelo Vincent      avincent@live
# 1        ha127   563     Hubert Arnold     harnold@yandex
# 2        lg794    65      Loris Goulet     lgoulet@yandex
# 3        tb566   563  Teodora Brunelli  tbrunelli@outlook
# 4        lh506   563        Lexie Hunt         lhunt@live
# ...        ...   ...               ...                ...
# 8170     st581    65   Serita Thebault   sthebault@yandex
# 8171     gf637   563   Glenn Foerstner   gfoerstner@yahoo
# 8172     rc983  1114       Robt Collin    rcollin@outlook
# 8173     cz381    65      Corina Zappa     czappa@outlook
# 8174     fg535    65     Freeman Gibbs     fgibbs@outlook
#
# [8175 rows x 5 columns]

# %%
# Create a new DataFrame with the appropriate columns.
backer_extracted_df = pd.DataFrame()
backer_extracted_df['backer_id'] = backer_df['backer_id']
backer_extracted_df['cf_id'] = backer_df['cf_id']
backer_extracted_df['name'] = backer_df['name']
backer_extracted_df['email'] = backer_df['email']
backer_extracted_df
# Out:
#      backer_id cf_id              name              email
# 0        av166   968    Angelo Vincent      avincent@live
# 1        ha127   563     Hubert Arnold     harnold@yandex
# 2        lg794    65      Loris Goulet     lgoulet@yandex
# 3        tb566   563  Teodora Brunelli  tbrunelli@outlook
# 4        lh506   563        Lexie Hunt         lhunt@live
# ...        ...   ...               ...                ...
# 8170     st581    65   Serita Thebault   sthebault@yandex
# 8171     gf637   563   Glenn Foerstner   gfoerstner@yahoo
# 8172     rc983  1114       Robt Collin    rcollin@outlook
# 8173     cz381    65      Corina Zappa     czappa@outlook
# 8174     fg535    65     Freeman Gibbs     fgibbs@outlook
#
# [8175 rows x 4 columns]

# %%
# Export the DataFrame as a CSV file using encoding='utf8'.
backer_extracted_df.to_csv('Resources/backer_data.csv', encoding='utf8')

# %% [markdown]
# ## Deliverable 2: Transform and Clean Data
# ----
# 1. Check the data types of the columns and convert the "cf_id" column to an integer, if necessary.
# 2. Split the name in the "name" column into first and last names, and add them to "first_name" and "last_name" columns in the DataFrame.
# 3. Drop the "name" column in the DataFrame.
# 4. Place the columns in the following order; "backer_id", "cf_id", "first_name", "last_name" and "email".

# %%
# Check data types.
backer_extracted_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8175 entries, 0 to 8174
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   backer_id  8175 non-null   object
#  1   cf_id      8175 non-null   object
#  2   name       8175 non-null   object
#  3   email      8175 non-null   object
# dtypes: object(4)
# memory usage: 255.6+ KB

# %%
# Convert cf_id to an integer if necessa

backer_extracted_df['cf_id'] = pd.to_numeric(backer_extracted_df['cf_id'])
backer_extracted_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8175 entries, 0 to 8174
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   backer_id  8175 non-null   object
#  1   cf_id      8175 non-null   int64
#  2   name       8175 non-null   object
#  3   email      8175 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 255.6+ KB

# %%
# Split the "name" column into "first_name" and "last_name" columns.


backer_extracted_df[['first_name','last_name']] = backer_extracted_df['name'].str.split(" ", n=1, expand=True)
backer_extracted_df
# Out:
#      backer_id  cf_id              name              email first_name  \
# 0        av166    968    Angelo Vincent      avincent@live     Angelo
# 1        ha127    563     Hubert Arnold     harnold@yandex     Hubert
# 2        lg794     65      Loris Goulet     lgoulet@yandex      Loris
# 3        tb566    563  Teodora Brunelli  tbrunelli@outlook    Teodora
# 4        lh506    563        Lexie Hunt         lhunt@live      Lexie
# ...        ...    ...               ...                ...        ...
# 8170     st581     65   Serita Thebault   sthebault@yandex     Serita
# 8171     gf637    563   Glenn Foerstner   gfoerstner@yahoo      Glenn
# 8172     rc983   1114       Robt Collin    rcollin@outlook       Robt
# 8173     cz381     65      Corina Zappa     czappa@outlook     Corina
# 8174     fg535     65     Freeman Gibbs     fgibbs@outlook    Freeman
#
#       last_name
# 0       Vincent
# 1        Arnold
# 2        Goulet
# 3      Brunelli
# 4          Hunt
# ...         ...
# 8170   Thebault
# 8171  Foerstner
# 8172     Collin
# 8173      Zappa
# 8174      Gibbs
#
# [8175 rows x 6 columns]

# %%
#  Drop the name column
backer_clean_df = backer_extracted_df.drop(['name'], axis=1)

# Reorder the columns
backer_final_df = backer_extracted_df[['backer_id','cf_id','first_name','last_name','email']]
backer_final_df
# Out:
#      backer_id  cf_id first_name  last_name              email
# 0        av166    968     Angelo    Vincent      avincent@live
# 1        ha127    563     Hubert     Arnold     harnold@yandex
# 2        lg794     65      Loris     Goulet     lgoulet@yandex
# 3        tb566    563    Teodora   Brunelli  tbrunelli@outlook
# 4        lh506    563      Lexie       Hunt         lhunt@live
# ...        ...    ...        ...        ...                ...
# 8170     st581     65     Serita   Thebault   sthebault@yandex
# 8171     gf637    563      Glenn  Foerstner   gfoerstner@yahoo
# 8172     rc983   1114       Robt     Collin    rcollin@outlook
# 8173     cz381     65     Corina      Zappa     czappa@outlook
# 8174     fg535     65    Freeman      Gibbs     fgibbs@outlook
#
# [8175 rows x 5 columns]

# %%
# Export the DataFrame as a CSV file using encoding='utf8'.
backer_final_df.to_csv('Resources/backers.csv', encoding='utf8')

# %%
backer_final_df
# Out:
#      backer_id  cf_id first_name  last_name              email
# 0        av166    968     Angelo    Vincent      avincent@live
# 1        ha127    563     Hubert     Arnold     harnold@yandex
# 2        lg794     65      Loris     Goulet     lgoulet@yandex
# 3        tb566    563    Teodora   Brunelli  tbrunelli@outlook
# 4        lh506    563      Lexie       Hunt         lhunt@live
# ...        ...    ...        ...        ...                ...
# 8170     st581     65     Serita   Thebault   sthebault@yandex
# 8171     gf637    563      Glenn  Foerstner   gfoerstner@yahoo
# 8172     rc983   1114       Robt     Collin    rcollin@outlook
# 8173     cz381     65     Corina      Zappa     czappa@outlook
# 8174     fg535     65    Freeman      Gibbs     fgibbs@outlook
#
# [8175 rows x 5 columns]

# %%
backer_final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8175 entries, 0 to 8174
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   backer_id   8175 non-null   object
#  1   cf_id       8175 non-null   int64
#  2   first_name  8175 non-null   object
#  3   last_name   8175 non-null   object
#  4   email       8175 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 319.5+ KB
